# %%
import pandas as pd
from pandas_profiling import ProfileReport
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_27032\3034448462.py:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
#      -------------------------------------- 324.4/324.4 kB 6.7 MB/s eta 0:00:00
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.0.0-py2.py3-none-any.whl (344 kB)
#      ------------------------------------- 344.5/344.5 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in d:\downloads\anaconda\lib\site-packages (from ydata-profiling->pandas-profiling) (0.11.2)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in d:\downloads\anaconda\lib\site-packages (from ydata-profiling->pandas-profiling) (1.21.5)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in d:\downloads\anaconda\lib\site-packages (from ydata-profiling->pandas-profiling) (1.9.1)
# Collecting multimethod<1.10,>=1.4
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in d:\downloads\anaconda\lib\site-packages (from ydata-profiling->pandas-profiling) (2.11.3)
# Collecting phik<0.13,>=0.11.1
#   Downloading phik-0.12.3-cp39-cp39-win_amd64.whl (663 kB)
#      -------------------------------------- 663.5/663.5 kB 8.4 MB/s eta 0:00:00
# Collecting visions[type_image_path]==0.7.5
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      -------------------------------------- 102.7/102.7 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in d:\downloads\anaconda\lib\site-packages (from ydata-profiling->pandas-profiling) (0.13.2)
# Collecting pydantic<1.11,>=1.8.1
#   Downloading pydantic-1.10.5-cp39-cp39-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib<3.7,>=3.2 in d:\downloads\anaconda\lib\site-packages (from ydata-profiling->pandas-profiling) (3.5.2)
# Requirement already satisfied: requests<2.29,>=2.24.0 in d:\downloads\anaconda\lib\site-packages (from ydata-profiling->pandas-profiling) (2.28.1)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in d:\downloads\anaconda\lib\site-packages (from ydata-profiling->pandas-profiling) (4.64.1)
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in d:\downloads\anaconda\lib\site-packages (from ydata-profiling->pandas-profiling) (1.4.4)
# Collecting typeguard<2.14,>=2.13.2
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in d:\downloads\anaconda\lib\site-packages (from ydata-profiling->pandas-profiling) (6.0)
# Collecting htmlmin==0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: networkx>=2.4 in d:\downloads\anaconda\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (2.8.4)
# Collecting tangled-up-in-unicode>=0.0.4
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.3.0 in d:\downloads\anaconda\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (21.4.0)
# Requirement already satisfied: Pillow in d:\downloads\anaconda\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (9.2.0)
# Collecting imagehash
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ------------------------------------- 296.5/296.5 kB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=0.23 in d:\downloads\anaconda\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (2.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\downloads\anaconda\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\downloads\anaconda\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in d:\downloads\anaconda\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\downloads\anaconda\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in d:\downloads\anaconda\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\downloads\anaconda\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in d:\downloads\anaconda\lib\site-packages (from pandas!=1.4.0,<1.6,>1.1->ydata-profiling->pandas-profiling) (2022.1)
# Requirement already satisfied: joblib>=0.14.1 in d:\downloads\anaconda\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in d:\downloads\anaconda\lib\site-packages (from pydantic<1.11,>=1.8.1->ydata-profiling->pandas-profiling) (4.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\downloads\anaconda\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in d:\downloads\anaconda\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\downloads\anaconda\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\downloads\anaconda\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (3.3)
# Requirement already satisfied: patsy>=0.5.2 in d:\downloads\anaconda\lib\site-packages (from statsmodels<0.14,>=0.13.2->ydata-profiling->pandas-profiling) (0.5.2)
# Requirement already satisfied: colorama in d:\downloads\anaconda\lib\site-packages (from tqdm<4.65,>=4.48.2->ydata-profiling->pandas-profiling) (0.4.5)
# Requirement already satisfied: six in d:\downloads\anaconda\lib\site-packages (from patsy>=0.5.2->statsmodels<0.14,>=0.13.2->ydata-profiling->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in d:\downloads\anaconda\lib\site-packages (from imagehash->visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (1.3.0)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27082 sha256=dbdb355e3c19ab83970e06c05d6e05b6423fe2632ed9dafa9add820bf49bdf55
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\1d\05\04\c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
# Successfully built htmlmin
# Installing collected packages: htmlmin, typeguard, tangled-up-in-unicode, pydantic, multimethod, imagehash, visions, phik, ydata-profiling, pandas-profiling
# Successfully installed htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.9.1 pandas-profiling-3.6.6 phik-0.12.3 pydantic-1.10.5 tangled-up-in-unicode-0.2.0 typeguard-2.13.3 visions-0.7.5 ydata-profiling-4.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
url = "https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/cases_malaysia.csv"
data = pd.read_csv(url)

data.set_index('date', inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1125 entries, 2020-01-25 to 2023-02-22
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   cases_new                1125 non-null   int64
#  1   cases_import             1125 non-null   int64
#  2   cases_recovered          1125 non-null   int64
#  3   cases_active             1125 non-null   int64
#  4   cases_cluster            1125 non-null   int64
#  5   cases_unvax              1125 non-null   int64
#  6   cases_pvax               1125 non-null   int64
#  7   cases_fvax               1125 non-null   int64
#  8   cases_boost              1125 non-null   int64
#  9   cases_child              1125 non-null   int64
#  10  cases_adolescent         1125 non-null   int64
#  11  cases_adult              1125 non-null   int64
#  12  cases_elderly            1125 non-null   int64
#  13  cases_0_4                1125 non-null   int64
#  14  cases_5_11               1125 non-null   int64
#  15  cases_12_17              1125 non-null   int64
#  16  cases_18_29              1125 non-null   int64
#  17  cases_30_39              1125 non-null   int64
#  18  cases_40_49              1125 non-null   int64
#  19  cases_50_59              1125 non-null   int64
#  20  cases_60_69              1125 non-null   int64
#  21  cases_70_79              1125 non-null   int64
#  22  cases_80                 1125 non-null   int64
#  23  cluster_import           763 non-null    float64
#  24  cluster_religious        763 non-null    float64
#  25  cluster_community        763 non-null    float64
#  26  cluster_highRisk         763 non-null    float64
#  27  cluster_education        763 non-null    float64
#  28  cluster_detentionCentre  763 non-null    float64
#  29  cluster_workplace        763 non-null    float64
# dtypes: float64(7), int64(23)
# memory usage: 272.5+ KB

# %%
data.head()
# Out:
#             cases_new  cases_import  cases_recovered  cases_active  \
# date
# 2020-01-25          4             4                0             4
# 2020-01-26          0             0                0             4
# 2020-01-27          0             0                0             4
# 2020-01-28          0             0                0             4
# 2020-01-29          3             3                0             7
#
#             cases_cluster  cases_unvax  cases_pvax  cases_fvax  cases_boost  \
# date
# 2020-01-25              0            4           0           0            0
# 2020-01-26              0            0           0           0            0
# 2020-01-27              0            0           0           0            0
# 2020-01-28              0            0           0           0            0
# 2020-01-29              0            3           0           0            0
#
#             cases_child  ...  cases_60_69  cases_70_79  cases_80  \
# date                     ...
# 2020-01-25            0  ...            0            0         0
# 2020-01-26            0  ...            0            0         0
# 2020-01-27            0  ...            0            0         0
# 2020-01-28            0  ...            0            0         0
# 2020-01-29            1  ...            0            0         0
#
#             cluster_import  cluster_religious  cluster_community  \
# date
# 2020-01-25             NaN                NaN                NaN
# 2020-01-26             NaN                NaN                NaN
# 2020-01-27             NaN                NaN                NaN
# 2020-01-28             NaN                NaN                NaN
# 2020-01-29             NaN                NaN                NaN
#
#             cluster_highRisk  cluster_education  cluster_detentionCentre  \
# date
# 2020-01-25               NaN                NaN                      NaN
# 2020-01-26               NaN                NaN                      NaN
# 2020-01-27               NaN                NaN                      NaN
# 2020-01-28               NaN                NaN                      NaN
# 2020-01-29               NaN                NaN                      NaN
#
#             cluster_workplace
# date
# 2020-01-25                NaN
# 2020-01-26                NaN
# 2020-01-27                NaN
# 2020-01-28                NaN
# 2020-01-29                NaN
#
# [5 rows x 30 columns]

# %%
profile = ProfileReport(data, title='Pandas Profiling Report', html={'style':{'full_width':True}}, tsmode= True)
profile.to_file("output.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
